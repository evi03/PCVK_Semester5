# %% [markdown]
# <a href="https://colab.research.google.com/github/evi03/PCVK_Semester5/blob/main/week01_Evi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **STEP 1**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# **STEP 2**

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
       "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
      "https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# **STEP 3**

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# **STEP 4**

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


#garis horizontal tanpa loop
image_3[int(tinggi/2),:]=[255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
'''
#membuat garis horizontal ditengah image
for y in range (lebar): 0,1,2,....399
  image_3[int((tinggi)/2),y] = [255,255,255]
'''
'''
#membuat garis vertikal ditengah image
for x in range (tinggi):
  image_3[x,int((lebar)/2)] = [255,255,255]
'''
'''
#membuat garis diagonal
for y in range (tinggi):
  image_3[y,int(y*(lebar/tinggi))] = [255,0,0]
  image_3[y,lebar-1-int(y*(lebar/tinggi))] = [0,255,0]
'''
'''
#membuat garis horisontal ditengah dengan panjang tertentu
for y in range (100,200):
  image_3[int((tinggi)/2),y] = [255,255,255]
'''

#membuat kotak dari kumpulan pixel warna putih
for y in range (100,200):
  for x in range (100,200):
    image_3[x,y] = [255,255,255]


final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# **TUGAS KELOMPOK MENGGUNAKAN TUGAS UNTUK KELOMPOK 5 Menutupik bagian Agama dan Status Kawin**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Kode diatas digunakan untuk menghubungkan google Colab dengan Google Drive**

# %%
img_4 = cv.imread('/content/drive/MyDrive/contohKtp.jpg') #digunakan untuk membaca citra dari lokasi file drive kemudian mengubahnya ke dalam array 'img_4'
img_5 = cv.cvtColor(img_4, cv.COLOR_BGR2RGB) #digunakan untuk mengubah skema warna citra diari BGR menjadi RGB
cv2_imshow(img_4)
plt.imshow(img_5)
# Out:
# <PIL.Image.Image image mode=RGB size=429x280>

# %% [markdown]
# **Kode diatas digunakan untuk memangil/menampilkan alamat foto ktp dari Google Drive**

# %%
img_4s = np.copy(img_4) #fungsinya untuk menyalin array 'img_4' menjadi array 'img_4s'
#tutup bagian Agama
for y in range (120,155): #menutup dengan arah horizontal dari ukuran 120 sampai dengan 190
  for x in range (175,185): #menutup dengan arah Vertikal dari ukuran 180 sampai dengan 195
    img_4s[x,y] = [0,0,0] #digunakan untuk menentukan warna untuk menutupi bagian Agama dengan kode warna RGB 0,0,0

#tutup bagian Status Perkawinan
img_4ss = np.copy(img_4s) #fungsi kode disamping adalah untuk menyalin gambar foto ktp pada array 'img_4s menjadi gambar baru ke dalam array img_4ss'
for y in range (120,205): #menutup dengan arah horizontal dari ukuran 120 sampai dengan 205
  for x in range (187,196): #menutup dengan arah vertikal dari ukuran 187 sampai dengan 196
    img_4ss[x,y] = [0,255,255] #digunakan untuk menentukan warna untuk menutupi bagian Status Perkawinan dengan kode warna RGB 0,255,255
final_frame = cv.hconcat((img_4, img_4ss)) #gunanya adalah untuk mengabungkan gambar dari citra pertama img_4 dan img_4ss
cv2_imshow(final_frame) #menampilkan final_frame
# Out:
# <PIL.Image.Image image mode=RGB size=858x280>
